# %% [markdown]
# ### Printing Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
Print("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 Print("hello")
#
# NameError: name 'Print' is not defined

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
print('hello') ## single inverted comma also works
# Out:
# hello

# %%
print(10)
# Out:
# 10

# %%
print(10.5)
# Out:
# 10.5

# %% [markdown]
# ### Shortcut keys

# %% [markdown]
# ##### 1.Shift+Enter => Run
# ##### 2.Insert cell above => a
# ##### 3.Insert cell below => b
# ##### 4.Delete a cell => d,d or X
